# %%
import pandas as pd

df = pd.read_csv("hacktrain.csv")
print(df.shape)
# Out:
# (8000, 30)

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'ID', 'class', '20150720_N', '20150602_N', '20150517_N',
#        '20150501_N', '20150415_N', '20150330_N', '20150314_N', '20150226_N',
#        '20150210_N', '20150125_N', '20150109_N', '20141117_N', '20141101_N',
#        '20141016_N', '20140930_N', '20140813_N', '20140626_N', '20140610_N',
#        '20140525_N', '20140509_N', '20140423_N', '20140407_N', '20140322_N',
#        '20140218_N', '20140202_N', '20140117_N', '20140101_N'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 30 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  8000 non-null   int64
#  1   ID          8000 non-null   int64
#  2   class       8000 non-null   object
#  3   20150720_N  7440 non-null   float64
#  4   20150602_N  6800 non-null   float64
#  5   20150517_N  7200 non-null   float64
#  6   20150501_N  7040 non-null   float64
#  7   20150415_N  7520 non-null   float64
#  8   20150330_N  6880 non-null   float64
#  9   20150314_N  7280 non-null   float64
#  10  20150226_N  6640 non-null   float64
#  11  20150210_N  7360 non-null   float64
#  12  20150125_N  6960 non-null   float64
#  13  20150109_N  7120 non-null   float64
#  14  20141117_N  6720 non-null   float64
#  15  20141101_N  7600 non-null   float64
#  16  20141016_N  6560 non-null   float64
#  17  20140930_N  7200 non-null   float64
# ...

# %%
print(df.head())
# Out:
#    Unnamed: 0  ID  class  20150720_N  20150602_N  20150517_N  20150501_N  \
# 0           0   1  water    637.5950     658.668   -1882.030    -1924.36
# 1           1   2  water    634.2400     593.705   -1625.790    -1672.32
# 2           3   4  water     58.0174   -1599.160         NaN    -1052.63
# 3           4   5  water     72.5180         NaN     380.436    -1256.93
# 4           7   8  water   1136.4400         NaN         NaN     1647.83
#
#    20150415_N  20150330_N  20150314_N  ...  20140610_N  20140525_N  \
# 0     997.904   -1739.990     630.087  ...         NaN   -1043.160
# 1     914.198    -692.386     707.626  ...         NaN    -933.934
# 2         NaN   -1564.630         NaN  ...    -1025.88     368.622
# 3     515.805   -1413.180    -802.942  ...    -1813.95     155.624
# 4    1935.800         NaN    2158.980  ...     1535.00    1959.430
#
#    20140509_N  20140423_N  20140407_N  20140322_N  20140218_N  20140202_N  \
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  ID  class  20150720_N  20150602_N  20150517_N  20150501_N  \
# 0           0   1  water    637.5950     658.668   -1882.030    -1924.36
# 1           1   2  water    634.2400     593.705   -1625.790    -1672.32
# 2           3   4  water     58.0174   -1599.160         NaN    -1052.63
# 3           4   5  water     72.5180         NaN     380.436    -1256.93
# 4           7   8  water   1136.4400         NaN         NaN     1647.83
#
#    20150415_N  20150330_N  20150314_N  ...  20140610_N  20140525_N  \
# 0     997.904   -1739.990     630.087  ...         NaN   -1043.160
# 1     914.198    -692.386     707.626  ...         NaN    -933.934
# 2         NaN   -1564.630         NaN  ...    -1025.88     368.622
# 3     515.805   -1413.180    -802.942  ...    -1813.95     155.624
# 4    1935.800         NaN    2158.980  ...     1535.00    1959.430
#
#    20140509_N  20140423_N  20140407_N  20140322_N  20140218_N  20140202_N  \
# ...

# %%
print(df['class'].value_counts())
# Out:
# class
# forest        6159
# farm           841
# impervious     669
# grass          196
# water          105
# orchard         30
# Name: count, dtype: int64

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0       0
# ID               0
# class            0
# 20150720_N     560
# 20150602_N    1200
# 20150517_N     800
# 20150501_N     960
# 20150415_N     480
# 20150330_N    1120
# 20150314_N     720
# 20150226_N    1360
# 20150210_N     640
# 20150125_N    1040
# 20150109_N     880
# 20141117_N    1280
# 20141101_N     400
# 20141016_N    1440
# 20140930_N     800
# 20140813_N     560
# 20140626_N    1600
# 20140610_N     480
# 20140525_N     720
# 20140509_N     880
# 20140423_N    1760
# 20140407_N     640
# 20140322_N    1120
# 20140218_N    1440
# 20140202_N     560
# 20140117_N    1200
# 20140101_N     400
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['class'] = le.fit_transform(df['class'])

# %%
print(df.columns.tolist())
# Out:
# ['Unnamed: 0', 'ID', 'class', '20150720_N', '20150602_N', '20150517_N', '20150501_N', '20150415_N', '20150330_N', '20150314_N', '20150226_N', '20150210_N', '20150125_N', '20150109_N', '20141117_N', '20141101_N', '20141016_N', '20140930_N', '20140813_N', '20140626_N', '20140610_N', '20140525_N', '20140509_N', '20140423_N', '20140407_N', '20140322_N', '20140218_N', '20140202_N', '20140117_N', '20140101_N']

# %%
df.drop(columns=['ID','Unnamed: 0'], inplace=True)

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
import numpy as np

x = df.drop(columns=['class'])
y = df['class']

imp = IterativeImputer(random_state=42, max_iter=15)
x_imputed = imp.fit_transform(x)

# %%
x_imputed_df = pd.DataFrame(x_imputed, columns=x.columns)
x_imputed_df['mean_ndvi'] = x_imputed_df.mean(axis=1)    #To extract time series features
x_imputed_df['std_ndvi'] = x_imputed_df.std(axis=1)
x_imputed_df['trend'] = x_imputed_df.apply(lambda row: np.polyfit(np.arange(len(row)), row, 1)[0], axis=1) #To calculate the slope

# %%
x_imputed_df.head()
# Out:
#    20150720_N   20150602_N   20150517_N  20150501_N   20150415_N   20150330_N  \
# 0    637.5950   658.668000 -1882.030000    -1924.36   997.904000 -1739.990000
# 1    634.2400   593.705000 -1625.790000    -1672.32   914.198000  -692.386000
# 2     58.0174 -1599.160000  -677.181682    -1052.63  -637.124819 -1564.630000
# 3     72.5180  -228.653446   380.436000    -1256.93   515.805000 -1413.180000
# 4   1136.4400   544.985988   908.298193     1647.83  1935.800000   737.072139
#
#     20150314_N   20150226_N  20150210_N   20150125_N  ...  20140423_N  \
# 0   630.087000 -1023.190641    -1325.64  -944.084000  ...     267.138
# 1   707.626000 -1670.590000    -1408.64  -989.285000  ...     120.059
# 2   742.313751   729.790000    -3162.14 -3704.806447  ...   -1227.800
# 3  -802.942000   683.254000    -2829.40 -1267.540000  ...    -924.073
# 4  2158.980000  1089.245236     1242.87 -2646.050000  ...    -384.915
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_scaled = scaler.fit_transform(x_imputed_df)

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x_scaled, y, test_size=0.2, random_state=42, stratify=y)

sm = SMOTE(random_state=42)
x_train_sm, y_train_sm = sm.fit_resample(x_train, y_train)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(
    solver='lbfgs',
    multi_class='multinomial',
    max_iter=2000,
    class_weight='balanced',
    C=10, #For regularization 
    random_state=42
)
model.fit(x_train_sm, y_train_sm)
# Out:
# C:\Users\yasha\.conda\envs\tf-gpu\lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# LogisticRegression(C=10, class_weight='balanced', max_iter=2000,
#                    multi_class='multinomial', random_state=42)

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(x_test)

# %%
from sklearn.metrics import classification_report

y_pred = model.predict(x_test)

print(classification_report(y_test, y_pred, target_names=le.classes_))
# Out:
#               precision    recall  f1-score   support
#
#         farm       0.57      0.67      0.61       168
#       forest       0.97      0.84      0.90      1232
#        grass       0.37      0.62      0.46        39
#   impervious       0.82      0.81      0.82       134
#      orchard       0.06      0.83      0.12         6
#        water       0.29      0.81      0.43        21
#
#     accuracy                           0.82      1600
#    macro avg       0.51      0.76      0.56      1600
# weighted avg       0.89      0.82      0.84      1600

# %%
from sklearn.model_selection import StratifiedKFold,cross_val_score
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
cv_scores = cross_val_score(model, x_scaled, y, cv=cv, scoring='accuracy')
print("Stratified CV Accuracy:", np.mean(cv_scores))
# Out:
# C:\Users\yasha\.conda\envs\tf-gpu\lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\yasha\.conda\envs\tf-gpu\lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# C:\Users\yasha\.conda\envs\tf-gpu\lib\site-packages\sklearn\linear_model\_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# ...

# %%
test_data = pd.read_csv("hacktest.csv")
ID = test_data['ID']
test_data.drop(columns=['ID', 'Unnamed: 0'], inplace=True, errors='ignore')
imp = IterativeImputer(random_state=42, max_iter=15)
test_imputed = imp.fit_transform(test_data)
test_imputed_df = pd.DataFrame(test_imputed, columns=test_data.columns)

# %%
test_imputed_df['mean_ndvi'] = test_imputed_df.mean(axis=1)
test_imputed_df['std_ndvi'] = test_imputed_df.std(axis=1)
test_imputed_df['trend'] = test_imputed_df.apply(
    lambda row: np.polyfit(np.arange(len(row)), row, 1)[0], axis=1
)

# %%
print(x_imputed_df.columns.tolist())
print(test_imputed_df.columns.tolist())
# Out:
# ['20150720_N', '20150602_N', '20150517_N', '20150501_N', '20150415_N', '20150330_N', '20150314_N', '20150226_N', '20150210_N', '20150125_N', '20150109_N', '20141117_N', '20141101_N', '20141016_N', '20140930_N', '20140813_N', '20140626_N', '20140610_N', '20140525_N', '20140509_N', '20140423_N', '20140407_N', '20140322_N', '20140218_N', '20140202_N', '20140117_N', '20140101_N', 'mean_ndvi', 'std_ndvi', 'trend']
# ['20150720_N', '20150602_N', '20150517_N', '20150501_N', '20150415_N', '20150330_N', '20150314_N', '20150226_N', '20150210_N', '20150125_N', '20150109_N', '20141117_N', '20141101_N', '20141016_N', '20140930_N', '20140813_N', '20140626_N', '20140610_N', '20140525_N', '20140509_N', '20140423_N', '20140407_N', '20140322_N', '20140218_N', '20140202_N', '20140117_N', '20140101_N', 'mean_ndvi', 'std_ndvi', 'trend']

# %%
test_scaled = scaler.fit_transform(test_imputed_df)

# %%
y_test_pred = model.predict(test_scaled)
y_decoded = le.inverse_transform(y_test_pred)

# %%
submission = pd.DataFrame({'ID': ID, 'class': y_decoded})
submission.to_csv("submission.csv", index=False)
